# %% [markdown]
# # Scan the dataset and give the inference as:
# ### 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.
# ### 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.
# ### 3. Create a box plot for each feature in the dataset.
# ### 4. Compare distributions and identify outliers.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ### 1. List down the features and their types (e.g., numeric, nominal) available in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### Observation:
# - 2 types of catrgorical data
# - ordinal or nominal
# - here ["Species"] order do not matters => nominal categorical data

# %% [markdown]
# ### 2. Create a histogram for each feature in the dataset to illustrate the feature distributions.

# %%
plt.hist(df["SepalLengthCm"],color="pink")
plt.xlabel("SepalLengthCm")
plt.ylabel("Count")
plt.title("Histogram for SepalLengthCm Vs Count")
# Out:
# Text(0.5, 1.0, 'Histogram for SepalLengthCm Vs Count')

# %%
plt.hist(df["SepalWidthCm"],color="blue")
plt.xlabel("SepalWidthCm")
plt.ylabel("Count")
plt.title("Histogram for SepalWidthCm Vs Count")
# Out:
# Text(0.5, 1.0, 'Histogram for SepalWidthCm Vs Count')

# %%
plt.hist(df["PetalLengthCm"],color="red")
plt.xlabel("PetalLengthCm")
plt.ylabel("Count")
plt.title("Histogram for PetalLengthCm Vs Count")
# Out:
# Text(0.5, 1.0, 'Histogram for PetalLengthCm Vs Count')

# %%
plt.hist(df["PetalWidthCm"],color="green")
plt.xlabel("PetalWidthCm")
plt.ylabel("Count")
plt.title("Histogram for PetalWidthCm Vs Count")
# Out:
# Text(0.5, 1.0, 'Histogram for PetalWidthCm Vs Count')

# %% [markdown]
# ### 3. Create a box plot for each feature in the dataset.

# %%
sns.boxplot(x=df["SepalLengthCm"],y=df["Species"],data=df)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Species'>

# %%
sns.boxplot(x=df["SepalWidthCm"],y=df["Species"],data=df)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Species'>

# %%
sns.boxplot(x=df["PetalLengthCm"],y=df["Species"],data=df)
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Species'>

# %%
sns.boxplot(x=df["PetalWidthCm"],y=df["Species"],data=df)
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Species'>

# %%
new_df = df[ {"SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"} ]
new_df
# Out:
#      SepalLengthCm  PetalLengthCm  PetalWidthCm  SepalWidthCm
# 0              5.1            1.4           0.2           3.5
# 1              4.9            1.4           0.2           3.0
# 2              4.7            1.3           0.2           3.2
# 3              4.6            1.5           0.2           3.1
# 4              5.0            1.4           0.2           3.6
# ..             ...            ...           ...           ...
# 145            6.7            5.2           2.3           3.0
# 146            6.3            5.0           1.9           2.5
# 147            6.5            5.2           2.0           3.0
# 148            6.2            5.4           2.3           3.4
# 149            5.9            5.1           1.8           3.0
#
# [150 rows x 4 columns]

# %%
sns.boxplot(new_df)
# Out:
# <Axes: >

# %% [markdown]
# ### 4. Compare distributions and identify outliers.
# - z-score
# - IQR
# - MinMax

# %%
upper_limit = (df["SepalWidthCm"].mean() + 3* df["SepalWidthCm"].std())
lower_limit = (df["SepalWidthCm"].mean() - 3 *df["SepalWidthCm"].std())

outliers = df[ (df["SepalWidthCm"]<lower_limit) | (df["SepalWidthCm"]>upper_limit) ] 
outliers
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa

# %%
removed_outliers = df[ (df["SepalWidthCm"]>lower_limit) & (df["SepalWidthCm"]<upper_limit)]
removed_outliers.iloc[10:18]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 17  18            5.1           3.5            1.4           0.3  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
